# %% [markdown]
# <a href="https://colab.research.google.com/github/OleksandrGavrylenko/8-puzzle-Python-bot/blob/master/Lesson2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Converting Celsius to Fahrenheit.
# First Model.
# f = 1.8 * c + 32

# %%
import tensorflow as tf
# tf.logging.set_verbosity(tf.logging.ERROR)

import numpy as np

# %%
celsius_q =    np.array([-40, -10,  0,  8, 15, 20, 22,  38], dtype=float)
fahrenheit_a = np.array([-40,  14, 32, 46, 59, 68, 72, 100], dtype=float)

# %%
for i, c in enumerate(celsius_q):
  print("{} degrees Celsius = {} degreees Fahrenheit".format(c, fahrenheit_a[i]))
# Out:
# -40.0 degrees Celsius = -40.0 degreees Fahrenheit
# -10.0 degrees Celsius = 14.0 degreees Fahrenheit
# 0.0 degrees Celsius = 32.0 degreees Fahrenheit
# 8.0 degrees Celsius = 46.0 degreees Fahrenheit
# 15.0 degrees Celsius = 59.0 degreees Fahrenheit
# 20.0 degrees Celsius = 68.0 degreees Fahrenheit
# 22.0 degrees Celsius = 72.0 degreees Fahrenheit
# 38.0 degrees Celsius = 100.0 degreees Fahrenheit

# %%
l0=tf.keras.layers.Dense(units=1, input_shape=[1])

# %%
model = tf.keras.Sequential([l0])

# %%
model.compile(loss='mean_squared_error', optimizer=tf.keras.optimizers.Adam(0.1))

# %%
history = model.fit(celsius_q, fahrenheit_a, epochs=500, verbose=True)
print("Finished training the model")
# Out:
# Epoch 1/500
# 1/1 [==============================] - 0s 2ms/step - loss: 9.0534
# Epoch 2/500
# 1/1 [==============================] - 0s 2ms/step - loss: 8.9346
# Epoch 3/500
# 1/1 [==============================] - 0s 2ms/step - loss: 8.8173
# Epoch 4/500
# 1/1 [==============================] - 0s 869us/step - loss: 8.7014
# Epoch 5/500
# 1/1 [==============================] - 0s 818us/step - loss: 8.5868
# Epoch 6/500
# 1/1 [==============================] - 0s 1ms/step - loss: 8.4736
# Epoch 7/500
# 1/1 [==============================] - 0s 2ms/step - loss: 8.3618
# Epoch 8/500
# 1/1 [==============================] - 0s 1ms/step - loss: 8.2513
# Epoch 9/500
# 1/1 [==============================] - 0s 2ms/step - loss: 8.1421
# Epoch 10/500
# 1/1 [==============================] - 0s 2ms/step - loss: 8.0343
# Epoch 11/500
# 1/1 [==============================] - 0s 2ms/step - loss: 7.9277
# Epoch 12/500
# 1/1 [==============================] - 0s 1ms/step - loss: 7.8225
# ...

# %%
import matplotlib.pyplot as plt

# %%
plt.xlabel('Epoch number')
plt.ylabel("Loss Magnitude")
plt.plot(history.history['loss'])

# %%
print(model.predict([100.0]))
# Out:
# [[211.79527]]

# %%
print("These are the layer variables: {}".format(l0.get_weights()))
# Out:
# These are the layer variables: [array([[1.7987005]], dtype=float32), array([31.925238], dtype=float32)]

# %% [markdown]
# Create the same model, but with 3 layers instead of 1 as before

# %%
# Create 3 layers
l0 = tf.keras.layers.Dense(units=4, input_shape=[1])
l1 = tf.keras.layers.Dense(units=4)
l2 = tf.keras.layers.Dense(units=1)

# %%
model = tf.keras.Sequential([l0, l1, l2])
model.compile(loss='mean_squared_error', optimizer=tf.keras.optimizers.Adam(0.1))

# %%
history = model.fit(celsius_q, fahrenheit_a, epochs=500, verbose=False)

# %%
print("Finished training the model")
# Out:
# Finished training the model

# %%
plt.xlabel('Epoch number')
plt.ylabel("Loss Magnitude")
plt.plot(history.history['loss'])

# %%
print(model.predict([100.0]))
# Out:
# [[211.78636]]

# %%
print("Model predicts that 100 degrees Celsius is: {} degrees Fahrenheit".format(model.predict([100.0])))
# Out:
# Model predicts that 100 degrees Celsius is: [[211.78636]] degrees Fahrenheit

# %%
print("These are the l0 weights: {}".format(l0.weights))
print("These are the l1 weights: {}".format(l1.weights))
print("These are the l2 weights: {}".format(l2.weights))
# Out:
# These are the l0 weights: [<tf.Variable 'dense_2/kernel:0' shape=(1, 4) dtype=float32, numpy=
# array([[-0.10140379, -0.11765144,  0.48625413, -0.39618134]],
#       dtype=float32)>, <tf.Variable 'dense_2/bias:0' shape=(4,) dtype=float32, numpy=array([ 1.2869558, -3.5093298,  3.6990974, -3.7041867], dtype=float32)>]
# These are the l1 weights: [<tf.Variable 'dense_3/kernel:0' shape=(4, 4) dtype=float32, numpy=
# array([[-0.8438121 , -0.048928  ,  0.10400122, -0.36287138],
#        [ 1.0426362 , -0.39995643,  0.5683499 ,  0.3544305 ],
#        [-0.39708903,  1.0902865 , -0.07551049,  0.42807168],
#        [ 0.54130054, -1.0646124 , -0.11911867,  0.05291408]],
#       dtype=float32)>, <tf.Variable 'dense_3/bias:0' shape=(4,) dtype=float32, numpy=array([-3.5051718,  3.3862648, -2.1533582,  2.9537585], dtype=float32)>]
# These are the l2 weights: [<tf.Variable 'dense_4/kernel:0' shape=(4, 1) dtype=float32, numpy=
# array([[-0.88085604],
#        [ 1.3377562 ],
#        [-0.15980376],
# ...
