# %% [markdown]
# <a href="https://colab.research.google.com/github/OleksandrGavrylenko/8-puzzle-Python-bot/blob/master/UdacityTFCourse1Lesson.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello World!")

# %%
# !pwd

# %%
# !ls -lah

# %%
import numpy as np

# %%
a = np.array(["Hello", "World"])
a = np.append(a, "!")
print("Current array: {}".format(a))
print("Printing each element")
for i in a:
  print(i)

print("\nPrinting each element and their index")
for i, e in enumerate(a):
  print("Index: {}, was: {}".format(i, e))

# %%
print("Showing some basic math on arrays")
b = np.array([0, 1, 4, 3, 2])
print("Max: {}".format(np.max(b)))
print("Average: {}".format(np.average(b)))
print("Max index: {}".format(np.argmax(b)))

# %%
c = np.random.rand(3, 3)
print(c)

# %%
print("\nYou can print the dimensions of arrays")
print("Shape of a: {}".format(a.shape))
print("Shape of b: {}".format(b.shape))
print("Shape of c: {}".format(c.shape))

# %%
print("Install numpy")
# !pip install numpy

# %%
# !pwd

# %%
# !ls -lah

# %%
# !cd /

# %%
# !ls -lah
